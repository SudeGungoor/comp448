# %% [markdown]
# <a href="https://colab.research.google.com/github/SudeGungoor/comp448/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os

# %%
a = np.arange(10)
a = a**2
print(a)
# Out:
# [ 0  1  4  9 16 25 36 49 64 81]
